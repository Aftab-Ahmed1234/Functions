# %% [markdown]
# # Functions

# %%
def my_function():
 print("This is first function")

my_function()
# Out:
# This is first function

# %%
def func():
    x=5 
    print(x)
func()
func()
# Out:
# 5
# 5

# %%
# Argument Funcions
def func(x):
    print(x)
func(10)
# Out:
# 10

# %%
x=5
def func():
    print(x)
func()
print(x)
# Out:
# 5
# 5

# %%
x=10
def func():
    x=5
    print(x)
func()
print(x)
# Out:
# 5
# 10

# %%
def func():
    global x
    x=5
    
func()
print(x)
# Out:
# 5

# %%
x=10
