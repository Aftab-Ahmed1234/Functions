# %% [markdown]
# # Functions

# %%
def my_function():
 print("This is first function")

my_function()
# Out:
# This is first function

# %%
def func():
    x=5 
    print(x)
func()
func()
# Out:
# 5
# 5

# %%
# Argument Funcions
def func(x):
    print(x)
func(10)
# Out:
# 10

# %%
x=5
def func():
    print(x)
func()
print(x)
# Out:
# 5
# 5

# %%
x=10
def func():
    x=5
    print(x)
func()
print(x)
# Out:
# 5
# 10

# %%
def func():
    global x
    x=5
    
func()
print(x)
# Out:
# 5

# %%
x=10
def func():
    global x
    x=5
func()
print(x)
# Out:
# 5

# %%
def func1():
 x=5
 print(x)
 def func2():
  nonlocal x
  x="Hello"
 func2()
 return x
print(func1())
# Out:
# 5
# Hello

# %%
def changecase(func):
 def myinner():
    return func().upper()
 return myinner
@changecase
def myfunction():
  return "Hello Sally"

print(myfunction())
# Out:
# HELLO SALLY

# %%
x= lambda a:a+10
print(x(5))
# Out:
# 15

# %%
x=lambda a,b:a*b
print(x(2,3))
# Out:
# 6

# %%
def countdown(n):
 if n<=0:
    print("Done!")
 else:
    print(n)
    countdown(n-1)
countdown(5)
# Out:
# 5
# 4
# 3
# 2
# 1
# Done!

# %%
amount=int(input("Enter amount"))
r1=amount%5000
fiveK=amount-r1
print(fivek)
r2=r1%1000
onek=r1-r2
# Out:
# Enter amount8880
