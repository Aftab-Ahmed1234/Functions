# %% [markdown]
# # Functions

# %%
def my_function():
 print("This is first function")

my_function()
# Out:
# This is first function

# %%
def func():
    x=5 
    print(x)
func()
func()
# Out:
# 5
# 5

# %%
# Argument Funcions
def func(x):
    print(x)
func(10)
# Out:
# 10

# %%
x=5
def func():
    print(x)
func()
print(x)
# Out:
# 5
# 5

# %%
x=10
def func():
    x=5
    print(x)
func()
print(x)
# Out:
# 5
# 10

# %%
def func():
    global x
    x=5
    
func()
print(x)
# Out:
# 5

# %%
x=10
def func():
    global x
    x=5
func()
print(x)
# Out:
# 5

# %%
def func1():
 x=5
 print(x)
 def func2():
  nonlocal x
  x="Hello"
 func2()
 return x
print(func1())
# Out:
# 5
# Hello

# %%
def changecase(func):
 def myinner():
    return func().upper()
 return myinner
@changecase
def myfunction():
  return "Hello Sally"

print(myfunction())
# Out:
# HELLO SALLY

# %%
x= lambda a:a+10
print(x(5))
# Out:
# 15

# %%
x=lambda a,b:a*b
print(x(2,3))
# Out:
# 6

# %%
def countdown(n):
 if n<=0:
    print("Done!")
 else:
    print(n)
    countdown(n-1)
countdown(5)
# Out:
# 5
# 4
# 3
# 2
# 1
# Done!

# %%
amount=int(input("Enter amount  :"))

r1=amount%5000
fk=amount-r1

fk==5000
note=fk/5000;
print("5000 notes are",int(note))

r2=r1%1000
ok=r1-r2
ok==1000
note=ok/1000;
print(" 1000 notes are",int(note))

r3=r2%500
fh=r2-r3
fh==500
note=fh/500;
print("500 notes are",int(note))
    

r4=r3%100
oh=r3-r4
oh==100
note=oh/100;
print("100 notes are",int(note))

r5=r4%50
fif=r4-r5
fif==50
note=fif/50;
print("50 notes are",int(note))

r6=r5%20
twenty=r5-r6
twenty==20
note=twenty/20;
print("20 notes are",int(note))

r7=r6%10
ten=r6-r7
ten==10
note=ten/10;
print("10 notes are",int(note))
# Out:
# Enter amount  :8880
# 5000 notes are 1
#  1000 notes are 3
# 500 notes are 1
# 100 notes are 3
# 50 notes are 1
# 20 notes are 1
# 10 notes are 1

# %%
amount = int(input("Enter amount: "))

notes = [5000, 1000, 500, 100, 50, 20, 10]

for note in notes:
    count = amount // note
    amount = amount % note
    print(f"{note} notes are {count}")
# Out:
# Enter amount: 7770
# 5000 notes are 1
# 1000 notes are 2
# 500 notes are 1
# 100 notes are 2
# 50 notes are 1
# 20 notes are 1
# 10 notes are 0

# %%
def factorial(n):
    if n==0 or n==1:
        return 1
    else:
        return n*factorial(n-1)
print(factorial(5))
# Out:
# 120

# %%
def fibonacii(n):
  if n<=1:
    return n
  else:
    return fibonacii(n-1)+fibonacii(n-1)
print(fibonacii(7))
# Out:
# 64

# %%
def sum_list(numbers):
    if len(numbers)==0:
     return 0
    else: 
     return numbers[0]+sum_list(numbers[1:])
my_list=[1,2,3,4,5]
print(sum_list(my_list))
# Out:
# 15

# %%
def find_max(numbers):
    if len(numbers)==1:
     return numbers[0]
    else:
     max_of_rest=find_max(numbers[1:])
     return numbers[0] if numbers[0]> max_of_rest else max_of_rest
my_list=[3,7,2,9,1]
print(find_max(my_list))
# Out:
# 9

# %%
import sys
print(sys.getrecursionlimit)
# Out:
# <built-in function getrecursionlimit>

# %%
import sys
sys.setrecursionlimit(2000)
print(sys.getrecursionlimit)
# Out:
# <built-in function getrecursionlimit>

# %%
def my_generator():
    yield 1
    yield 2
    yield 3
for value in my_generator():
    print(value)
# Out:
# 1
# 2
# 3
