# %% [markdown]
# # Functions

# %%
def my_function():
 print("This is first function")

my_function()
# Out:
# This is first function

# %%
def func():
    x=5 
    print(x)
func()
func()
# Out:
# 5
# 5

# %%
# Argument Funcions
def func(x):
    print(x)
func(10)
# Out:
# 10
